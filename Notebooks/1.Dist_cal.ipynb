# %%
from ortools.linear_solver import pywraplp

# %%
import pickle
import numpy as np

# Loading the list from the pickle file
file_path = r"F:\dist_list.pickle"  # Update the file path if necessary

with open(file_path, 'rb') as file:
    dist_list = pickle.load(file)

print("Dist list loaded successfully.")
print(np.shape(dist_list))
# Out:
# Dist list loaded successfully.
# (400, 10450)

# %%
dist_list =  np.transpose(dist_list, (1, 0))

# %%
costs = [
    [90, 80, 75, 70],
    [35, 85, 55, 65],
    [125, 95, 90, 95],
    [45, 110, 95, 115],
    [60, 120, 50, 100],
    [50, 100, 90, 400],
    [50, 200, 170, 120],
    [50, 200, 190, 160]
]
num_workers = len(costs)
num_tasks = len(costs[0])
# Create the mip solver with the SCIP backend.
solver = pywraplp.Solver.CreateSolver("SCIP")

# x[i, j] is an array of 0-1 variables, which will be 1
# if worker i is assigned to task j.
x = {}
for i in range(num_workers):
    for j in range(num_tasks):
        x[i, j] = solver.IntVar(0, 1, "")
        
# Each worker is assigned to at most 1 task.
for i in range(num_workers):
    solver.Add(solver.Sum([x[i, j] for j in range(num_tasks)]) <= 1)

# Each task is assigned to exactly one worker.
for j in range(num_tasks):
    solver.Add(solver.Sum([x[i, j] for i in range(num_workers)]) == 1)
    
objective_terms = []
for i in range(num_workers):
    for j in range(num_tasks):
        objective_terms.append(costs[i][j] * x[i, j])
solver.Minimize(solver.Sum(objective_terms))
status = solver.Solve()
if status == pywraplp.Solver.OPTIMAL or status == pywraplp.Solver.FEASIBLE:
    print(f"Total cost = {solver.Objective().Value()}\n")
    for i in range(num_workers):
        for j in range(num_tasks):
            # Test if x[i,j] is 1 (with tolerance for floating point arithmetic).
            if x[i, j].solution_value() > 0.5:
                print(f"Worker {i} assigned to task {j}." + f" Cost: {costs[i][j]}")
else:
    print("No solution found.")
# Out:
# Total cost = 240.0
#
# Worker 0 assigned to task 1. Cost: 80
# Worker 1 assigned to task 3. Cost: 65
# Worker 3 assigned to task 0. Cost: 45
# Worker 4 assigned to task 2. Cost: 50

# %%
from tqdm import tqdm

costs = dist_list

num_workers = len(costs)
num_tasks = len(costs[0])
# Create the mip solver with the SCIP backend.
solver = pywraplp.Solver.CreateSolver("SCIP")

# x[i, j] is an array of 0-1 variables, which will be 1
# if worker i is assigned to task j.
x = {}
for i in range(num_workers):
    for j in range(num_tasks):
        x[i, j] = solver.IntVar(0, 1, "")
        
# Each worker is assigned to at most 1 task.
for i in range(num_workers):
    solver.Add(solver.Sum([x[i, j] for j in range(num_tasks)]) <= 1)

# Each task is assigned to exactly one worker.
for j in range(num_tasks):
    solver.Add(solver.Sum([x[i, j] for i in range(num_workers)]) == 1)
    
objective_terms = []
for i in tqdm(range(num_workers)):
    for j in range(num_tasks):
        objective_terms.append(costs[i][j] * x[i, j])
solver.Minimize(solver.Sum(objective_terms))

status = solver.Solve()

sol_indexes = []
if status == pywraplp.Solver.OPTIMAL or status == pywraplp.Solver.FEASIBLE:
    print(f"Total cost = {solver.Objective().Value()}\n")
    for i in range(num_workers):
        for j in range(num_tasks):
            # Test if x[i,j] is 1 (with tolerance for floating point arithmetic).
            if x[i, j].solution_value() > 0.1:
                print(f"Cluster {j} assigned to Class {i}." + f" Cost: {costs[i][j]}")
                sol_indexes.append(i)
else:
    print("No solution found.")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████
# Cluster 64 assigned to Class 8497. Cost: 12.943127408904369
# Cluster 168 assigned to Class 8529. Cost: 6.411388415752522
# Cluster 204 assigned to Class 8530. Cost: 10.63638515439814
# Cluster 237 assigned to Class 8975. Cost: 2.119114628588786
# Cluster 187 assigned to Class 8998. Cost: 1.6477550515394994
# Cluster 191 assigned to Class 9011. Cost: 8.417745269444415
# Cluster 86 assigned to Class 9012. Cost: 1.2760102092623784
# Cluster 238 assigned to Class 9040. Cost: 3.1254163752796784
# Cluster 125 assigned to Class 9059. Cost: 4.087865621717273
# Cluster 231 assigned to Class 9067. Cost: 2.089023219726738
# Cluster 329 assigned to Class 9069. Cost: 2.4674194107952014
# Cluster 142 assigned to Class 9071. Cost: 1.041121048429827
# Cluster 395 assigned to Class 9075. Cost: 2.563464389367304
# Cluster 374 assigned to Class 9079. Cost: 1.8194842853218565
# Cluster 349 assigned to Class 9088. Cost: 5.532034739999024
# Cluster 130 assigned to Class 9090. Cost: 6.45120113626999
# Cluster 65 assigned to Class 9092. Cost: 12.83990996970336
# Cluster 137 assigned to Class 9099. Cost: 3.3660451094187622
# Cluster 294 assigned to Class 9101. Cost: 2.6938274447427997
# Cluster 56 assigned to Class 9106. Cost: 7.791017784407713
# Cluster 207 assigned to Class 9107. Cost: 8.766703955910943
# Cluster 321 assigned to Class 9108. Cost: 6.936549597450915
# Cluster 10 assigned to Class 9110. Cost: 20.54939329581086
# Cluster 276 assigned to Class 9111. Cost: 1.8063537346001568
# Cluster 105 assigned to Class 9116. Cost: 4.165977377748709
# Cluster 386 assigned to Class 9126. Cost: 9.137115271248593
# Cluster 85 assigned to Class 9132. Cost: 3.815612728491104
# Cluster 131 assigned to Class 9162. Cost: 3.426855723545919
# Cluster 353 assigned to Class 9191. Cost: 2.8156119027174444
# Cluster 3 assigned to Class 9220. Cost: 0.9025971538153778
# Cluster 364 assigned to Class 9227. Cost: 1.9826026488380533
# Cluster 132 assigned to Class 9231. Cost: 1.9030488321407661
# Cluster 290 assigned to Class 9249. Cost: 1.2164436827900615
# Cluster 283 assigned to Class 9264. Cost: 2.1490062446063574
# Cluster 385 assigned to Class 9267. Cost: 0.866320434240225
# Cluster 94 assigned to Class 9274. Cost: 1.3175232068597362
# Cluster 248 assigned to Class 9279. Cost: 1.1650659459284691
# Cluster 136 assigned to Class 9283. Cost: 2.4006970589246173
# Cluster 270 assigned to Class 9284. Cost: 3.728855954244767
# Cluster 254 assigned to Class 9292. Cost: 2.3730977948518266
# Cluster 13 assigned to Class 9295. Cost: 2.7686607002512402
# Cluster 327 assigned to Class 9297. Cost: 4.621213377100871
# Cluster 127 assigned to Class 9304. Cost: 2.9825108350220786
# Cluster 265 assigned to Class 9346. Cost: 5.063060011704496
# Cluster 156 assigned to Class 9359. Cost: 1.2894793728003486
# Cluster 77 assigned to Class 9379. Cost: 1.1283889263953568
# Cluster 252 assigned to Class 9392. Cost: 1.9745349051836671
# Cluster 232 assigned to Class 9396. Cost: 3.0638082691151602
# Cluster 51 assigned to Class 9429. Cost: 6.593031205626937
# Cluster 199 assigned to Class 9435. Cost: 4.10696801691012
# Cluster 162 assigned to Class 9436. Cost: 10.295397469784191
# Cluster 314 assigned to Class 9438. Cost: 2.7000422860126787
# Cluster 99 assigned to Class 9447. Cost: 2.0708646767755217
# Cluster 214 assigned to Class 9450. Cost: 5.590923972581977
# Cluster 62 assigned to Class 9455. Cost: 2.2457200395851142
# Cluster 16 assigned to Class 9463. Cost: 3.382244446202832
# Cluster 45 assigned to Class 9464. Cost: 4.255281457447259
# Cluster 101 assigned to Class 9477. Cost: 2.2608279333065204
# Cluster 222 assigned to Class 9479. Cost: 5.927526523214798
# Cluster 264 assigned to Class 9483. Cost: 2.050547942129925
# Cluster 382 assigned to Class 9484. Cost: 5.714984519515659
# Cluster 341 assigned to Class 9489. Cost: 6.343465442029069
# Cluster 117 assigned to Class 9491. Cost: 3.1897271036986456
# Cluster 399 assigned to Class 9492. Cost: 6.476563379489669
# Cluster 22 assigned to Class 9497. Cost: 2.761990261713746
# Cluster 389 assigned to Class 9509. Cost: 5.503922482918508
# Cluster 287 assigned to Class 9542. Cost: 2.02842486818832
# Cluster 274 assigned to Class 9544. Cost: 6.828014845480632
# Cluster 90 assigned to Class 9545. Cost: 4.866264757014692
# Cluster 308 assigned to Class 9553. Cost: 2.4017783962088997
# Cluster 217 assigned to Class 9556. Cost: 6.896002576351434
# Cluster 289 assigned to Class 9559. Cost: 5.814699771369924
# Cluster 88 assigned to Class 9561. Cost: 4.0215665263918075
# Cluster 206 assigned to Class 9591. Cost: 3.161470878869018
# Cluster 211 assigned to Class 9599. Cost: 1.2291046977473559
# Cluster 244 assigned to Class 9642. Cost: 2.655969745653612
# Cluster 318 assigned to Class 9645. Cost: 3.3468924369754416
# Cluster 387 assigned to Class 9702. Cost: 5.005058575003206
# Cluster 368 assigned to Class 9705. Cost: 1.5729002215311674
# Cluster 165 assigned to Class 9749. Cost: 2.886203557631612
# Cluster 109 assigned to Class 9753. Cost: 1.4129457383954172
# Cluster 102 assigned to Class 9768. Cost: 1.4565070317521271
# Cluster 54 assigned to Class 9947. Cost: 12.787830297640788
# Cluster 263 assigned to Class 9950. Cost: 6.420653412688141
# Cluster 198 assigned to Class 9997. Cost: 8.117126906211437
# Cluster 140 assigned to Class 10008. Cost: 2.140499233196269
# Cluster 203 assigned to Class 10044. Cost: 4.134176812560928
# Cluster 53 assigned to Class 10045. Cost: 8.711982584296713
# Cluster 223 assigned to Class 10053. Cost: 10.855961567651882
# Cluster 235 assigned to Class 10056. Cost: 4.312814896997253
# Cluster 376 assigned to Class 10061. Cost: 7.482000621167752
# Cluster 296 assigned to Class 10142. Cost: 1.9450636145147635
# Cluster 184 assigned to Class 10202. Cost: 3.228197189667126
# Cluster 209 assigned to Class 10230. Cost: 1.8261649390382415
# Cluster 55 assigned to Class 10249. Cost: 2.8139960879331367
# Cluster 325 assigned to Class 10253. Cost: 2.8380608035423314
# Cluster 319 assigned to Class 10447. Cost: 10.008291481422887

# %%
import pickle

# Saving the list to a file in the D: drive
file_path = r"F:\index_list.pickle"  # r prefix is used for raw string to avoid escape characters

with open(file_path, 'wb') as file:
    pickle.dump(sol_indexes, file)

print("Combo list saved successfully.")
# Out:
# Combo list saved successfully.
