# %%
import os
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from tqdm import tqdm

# Define the path to the directory
directory_path = r"D:\datasets\Underwater_Image\WHOI\archive\dataset_pm\training"

# Initialize empty lists for images and labels
X_train = []
Y_train = []
class_label = 0

# Loop through subdirectories (classes)
for class_folder in tqdm(sorted(os.listdir(directory_path))):
    class_path = os.path.join(directory_path, class_folder)
    
    for image_file in os.listdir(class_path):
        if image_file.endswith('.png'):
            image_path = os.path.join(class_path, image_file)
            
            # Load image, convert to RGB and resize
            img = Image.open(image_path).convert('RGB')
            img = img.resize((32, 32))
            img_array = np.array(img)
            
            # Append image and label to lists
            X_train.append(img_array)
            Y_train.append(class_label)
            
    class_label = class_label + 1

# Convert lists to numpy arrays
X_train = np.array(X_train)
Y_train = np.array(Y_train)

print(f'X_train shape: {X_train.shape}')
print(f'Y_train shape: {Y_train.shape}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 16
#      13 class_label = 0
#      15 # Loop through subdirectories (classes)
# ---> 16 for class_folder in tqdm(sorted(os.listdir(directory_path))):
#      17     class_path = os.path.join(directory_path, class_folder)
#      19     for image_file in os.listdir(class_path):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:\\datasets\\Underwater_Image\\WHOI\\archive\\dataset_pm\\training'

# %%
import os
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from tqdm import tqdm

# Define the path to the directory
directory_path = r"D:\datasets\Underwater_Image\WHOI\archive\dataset_pm\validation"

# Initialize empty lists for images and labels
X_val = []
Y_val = []
class_label = 0

# Loop through subdirectories (classes)
for class_folder in tqdm(sorted(os.listdir(directory_path))):
    class_path = os.path.join(directory_path, class_folder)
    
    for image_file in os.listdir(class_path):
        if image_file.endswith('.png'):
            image_path = os.path.join(class_path, image_file)
            
            # Load image, convert to RGB and resize
            img = Image.open(image_path).convert('RGB')
            img = img.resize((32, 32))
            img_array = np.array(img)
            
            # Append image and label to lists
            X_val.append(img_array)
            Y_val.append(class_label)
            
    class_label = class_label + 1

# Convert lists to numpy arrays
X_val = np.array(X_val)
Y_val = np.array(Y_val)

print(f'X_train shape: {X_val.shape}')
print(f'Y_train shape: {Y_val.shape}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 16
#      13 class_label = 0
#      15 # Loop through subdirectories (classes)
# ---> 16 for class_folder in tqdm(sorted(os.listdir(directory_path))):
#      17     class_path = os.path.join(directory_path, class_folder)
#      19     for image_file in os.listdir(class_path):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:\\datasets\\Underwater_Image\\WHOI\\archive\\dataset_pm\\training'

# %%
import os
from PIL import Image
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from tqdm import tqdm

# Define the path to the directory
directory_path = r"D:\datasets\Underwater_Image\WHOI\archive\dataset_pm\test"

# Initialize empty lists for images and labels
X_test = []
Y_test = []
class_label = 0

# Loop through subdirectories (classes)
for class_folder in tqdm(sorted(os.listdir(directory_path))):
    class_path = os.path.join(directory_path, class_folder)
    
    for image_file in os.listdir(class_path):
        if image_file.endswith('.png'):
            image_path = os.path.join(class_path, image_file)
            
            # Load image, convert to RGB and resize
            img = Image.open(image_path).convert('RGB')
            img = img.resize((32, 32))
            img_array = np.array(img)
            
            # Append image and label to lists
            X_test.append(img_array)
            Y_test.append(class_label)
            
    class_label = class_label + 1

# Convert lists to numpy arrays
X_test = np.array(X_test)
Y_test = np.array(Y_test)

print(f'X_train shape: {X_test.shape}')

print(f'Y_train shape: {Y_test.shape}')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 16
#      13 class_label = 0
#      15 # Loop through subdirectories (classes)
# ---> 16 for class_folder in tqdm(sorted(os.listdir(directory_path))):
#      17     class_path = os.path.join(directory_path, class_folder)
#      19     for image_file in os.listdir(class_path):
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'D:\\datasets\\Underwater_Image\\WHOI\\archive\\dataset_pm\\training'

# %%
import tensorflow as tf
#tf.keras.backend.clear_session()
YT = to_categorical(Y_train)
VT = to_categorical(Y_val)

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.resnet import ResNet50, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
num_classes = 19
# Create the ResNet model without the top (fully connected) layers
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))    
model = Sequential()
model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dense(num_classes, activation='softmax'))  # Change units to match the number of classes
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
epochs = 50
model.fit(X_train,YT, epochs=epochs,batch_size=32, validation_data=(X_val,VT))
# Out:
# Epoch 1/100
# 90/90 [==============================] - 12s 72ms/step - loss: 2.0174 - accuracy: 0.5254 - val_loss: 62.3128 - val_accuracy: 0.0930
# Epoch 2/100
# 90/90 [==============================] - 6s 65ms/step - loss: 1.0400 - accuracy: 0.7416 - val_loss: 2.8289 - val_accuracy: 0.4443
# Epoch 3/100
# 90/90 [==============================] - 5s 52ms/step - loss: 1.1384 - accuracy: 0.7479 - val_loss: 294.9239 - val_accuracy: 0.0961
# Epoch 4/100
# 90/90 [==============================] - 3s 36ms/step - loss: 1.0856 - accuracy: 0.7723 - val_loss: 33.2929 - val_accuracy: 0.4178
# Epoch 5/100
# 90/90 [==============================] - 3s 35ms/step - loss: 1.1698 - accuracy: 0.7538 - val_loss: 389.3396 - val_accuracy: 0.2159
# Epoch 6/100
# 90/90 [==============================] - 3s 35ms/step - loss: 1.4756 - accuracy: 0.6685 - val_loss: 429.6486 - val_accuracy: 0.0996
# Epoch 7/100
# 90/90 [==============================] - 3s 34ms/step - loss: 1.6715 - accuracy: 0.6619 - val_loss: 10.0852 - val_accuracy: 0.2322
# Epoch 8/100
# 90/90 [==============================] - 3s 36ms/step - loss: 1.5604 - accuracy: 0.6636 - val_loss: 14.7097 - val_accuracy: 0.1542
# Epoch 9/100
# 90/90 [==============================] - 3s 37ms/step - loss: 1.2792 - accuracy: 0.7068 - val_loss: 1344.4772 - val_accuracy: 0.0665
# Epoch 10/100
# 90/90 [==============================] - 3s 37ms/step - loss: 1.6789 - accuracy: 0.6462 - val_loss: 12.0237 - val_accuracy: 0.2636
# Epoch 11/100
# Epoch 88/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.0576 - accuracy: 0.9815 - val_loss: 3.4921 - val_accuracy: 0.6459
# Epoch 89/100
# 90/90 [==============================] - 5s 54ms/step - loss: 0.1192 - accuracy: 0.9627 - val_loss: 2.6362 - val_accuracy: 0.6546
# Epoch 90/100
# 90/90 [==============================] - 5s 54ms/step - loss: 0.0644 - accuracy: 0.9805 - val_loss: 2.2624 - val_accuracy: 0.6309
# Epoch 91/100
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0749 - accuracy: 0.9805 - val_loss: 2.0688 - val_accuracy: 0.5905
# Epoch 92/100
# 90/90 [==============================] - 5s 55ms/step - loss: 0.0516 - accuracy: 0.9829 - val_loss: 1.1942 - val_accuracy: 0.7570
# Epoch 93/100
# 90/90 [==============================] - 5s 55ms/step - loss: 0.0533 - accuracy: 0.9854 - val_loss: 5.1009 - val_accuracy: 0.5272
# Epoch 94/100
# 90/90 [==============================] - 5s 55ms/step - loss: 0.0334 - accuracy: 0.9892 - val_loss: 1.5937 - val_accuracy: 0.7284
# Epoch 95/100
# 90/90 [==============================] - 5s 54ms/step - loss: 0.0780 - accuracy: 0.9742 - val_loss: 4.3560 - val_accuracy: 0.5320
# Epoch 96/100
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0518 - accuracy: 0.9857 - val_loss: 0.1639 - val_accuracy: 0.9537
# Epoch 97/100
# 90/90 [==============================] - 5s 59ms/step - loss: 0.0388 - accuracy: 0.9882 - val_loss: 1.6202 - val_accuracy: 0.8022
# Epoch 98/100
# 90/90 [==============================] - 5s 51ms/step - loss: 0.0839 - accuracy: 0.9746 - val_loss: 2.2809 - val_accuracy: 0.6320
# Epoch 99/100
# 90/90 [==============================] - 4s 46ms/step - loss: 0.0658 - accuracy: 0.9784 - val_loss: 1.2697 - val_accuracy: 0.7462
# Epoch 100/100
# 90/90 [==============================] - 4s 45ms/step - loss: 0.0653 - accuracy: 0.9812 - val_loss: 1.6568 - val_accuracy: 0.6751

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# Make predictions on the test dataset
predictions = model.predict(X_test)

# Convert one-hot encoded predictions back to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Calculate accuracy
accuracy = accuracy_score(Y_test, predicted_labels)

# Calculate F1 score
f1 = f1_score(Y_test, predicted_labels, average='weighted')

print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.6751392757660167
# F1 Score: 0.6493219331736974

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.resnet import ResNet50, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
num_classes = 19
model = keras.models.load_model(r"F:\Pre-Trained_Models\Pre-Trained_Models\whoi_32_model.h5")

x = model.layers[-4].output  # Access the last 4th layer from the end
x = GlobalAveragePooling2D(keepdims=False)(x)  # Explicitly specify keepdims
output = Dense(num_classes, activation='softmax')(x)
new_model = keras.models.Model(inputs=model.input, outputs=output)

# %%
new_model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
epochs = 50
new_model.fit(X_train,YT, epochs=epochs,batch_size=32, validation_data=(X_val,VT))
# Out:
# Epoch 1/100
# C:\Users\shaif\anaconda3\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
#
# 90/90 [==============================] - 5s 52ms/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.2820 - val_accuracy: 0.9109
# Epoch 96/100
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0351 - accuracy: 0.9906 - val_loss: 0.5785 - val_accuracy: 0.8607
# Epoch 97/100
# 90/90 [==============================] - 5s 53ms/step - loss: 0.0892 - accuracy: 0.9746 - val_loss: 0.0620 - val_accuracy: 0.9791
# Epoch 98/100
# 90/90 [==============================] - 5s 56ms/step - loss: 0.0752 - accuracy: 0.9777 - val_loss: 0.9559 - val_accuracy: 0.8029
# Epoch 99/100
# 90/90 [==============================] - 5s 56ms/step - loss: 0.0615 - accuracy: 0.9808 - val_loss: 2.2920 - val_accuracy: 0.6619
# Epoch 100/100
# 90/90 [==============================] - 5s 52ms/step - loss: 0.1020 - accuracy: 0.9763 - val_loss: 4.4567 - val_accuracy: 0.4641

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# Make predictions on the test dataset
predictions = new_model.predict(X_test)

# Convert one-hot encoded predictions back to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Calculate accuracy
accuracy = accuracy_score(Y_test, predicted_labels)

# Calculate F1 score
f1 = f1_score(Y_test, predicted_labels, average='weighted')

print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.46413649025069637
# F1 Score: 0.4518371904435395

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.resnet import ResNet50, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
num_classes = 19
model = keras.models.load_model(r"F:\Pre-Trained_Models\Pre-Trained_Models\rnd_32_model.h5")

x = model.layers[-4].output  # Access the last 4th layer from the end
x = GlobalAveragePooling2D(keepdims=False)(x)  # Explicitly specify keepdims
output = Dense(num_classes, activation='softmax')(x)
new_model = keras.models.Model(inputs=model.input, outputs=output) 
new_model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
epochs = 50
new_model.fit(X_train,YT, epochs=epochs,batch_size=32, validation_data=(X_val,VT))

# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix

# Make predictions on the test dataset
predictions = new_model.predict(X_test)

# Convert one-hot encoded predictions back to class labels
predicted_labels = np.argmax(predictions, axis=1)

# Calculate accuracy
accuracy = accuracy_score(Y_test, predicted_labels)

# Calculate F1 score
f1 = f1_score(Y_test, predicted_labels, average='weighted')

print(f"Accuracy: {accuracy}")
print(f"F1 Score: {f1}")

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.resnet import ResNet50, preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
num_classes = 19
model = keras.models.load_model(r"F:\Pre-Trained_Models\Pre-Trained_Models\rnd_32_model.h5")

x = model.layers[-4].output  # Access the last 4th layer from the end
x = GlobalAveragePooling2D(keepdims=False)(x)  # Explicitly specify keepdims
output = Dense(num_classes, activation='softmax')(x)
new_model = keras.models.Model(inputs=model.input, outputs=output) 
new_model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
epochs = 50
new_model.fit(X_train,YT, epochs=epochs,batch_size=32, validation_data=(X_val,VT))
