# %%
from ortools.linear_solver import pywraplp

# %%
import pickle
import numpy as np

# Loading the list from the pickle file
file_path = r"D:\dist_list.pickle"  # Update the file path if necessary

with open(file_path, 'rb') as file:
    dist_list = pickle.load(file)

print("Dist list loaded successfully.")
print(np.shape(dist_list))
# Out:
# Dist list loaded successfully.
# (400, 1000)

# %%
dist_list =  np.transpose(dist_list, (1, 0))

# %%
costs = [
    [90, 80, 75, 70],
    [35, 85, 55, 65],
    [125, 95, 90, 95],
    [45, 110, 95, 115],
    [60, 120, 50, 100],
    [50, 100, 90, 400],
    [50, 200, 170, 120],
    [50, 200, 190, 160]
]
num_workers = len(costs)
num_tasks = len(costs[0])
# Create the mip solver with the SCIP backend.
solver = pywraplp.Solver.CreateSolver("SCIP")

# x[i, j] is an array of 0-1 variables, which will be 1
# if worker i is assigned to task j.
x = {}
for i in range(num_workers):
    for j in range(num_tasks):
        x[i, j] = solver.IntVar(0, 1, "")
        
# Each worker is assigned to at most 1 task.
for i in range(num_workers):
    solver.Add(solver.Sum([x[i, j] for j in range(num_tasks)]) <= 1)

# Each task is assigned to exactly one worker.
for j in range(num_tasks):
    solver.Add(solver.Sum([x[i, j] for i in range(num_workers)]) == 1)
    
objective_terms = []
for i in range(num_workers):
    for j in range(num_tasks):
        objective_terms.append(costs[i][j] * x[i, j])
solver.Minimize(solver.Sum(objective_terms))
status = solver.Solve()
if status == pywraplp.Solver.OPTIMAL or status == pywraplp.Solver.FEASIBLE:
    print(f"Total cost = {solver.Objective().Value()}\n")
    for i in range(num_workers):
        for j in range(num_tasks):
            # Test if x[i,j] is 1 (with tolerance for floating point arithmetic).
            if x[i, j].solution_value() > 0.5:
                print(f"Worker {i} assigned to task {j}." + f" Cost: {costs[i][j]}")
else:
    print("No solution found.")
# Out:
# Total cost = 240.0
#
# Worker 0 assigned to task 1. Cost: 80
# Worker 1 assigned to task 3. Cost: 65
# Worker 3 assigned to task 0. Cost: 45
# Worker 4 assigned to task 2. Cost: 50

# %%
from tqdm import tqdm

costs = dist_list

num_workers = len(costs)
num_tasks = len(costs[0])
# Create the mip solver with the SCIP backend.
solver = pywraplp.Solver.CreateSolver("SCIP")

# x[i, j] is an array of 0-1 variables, which will be 1
# if worker i is assigned to task j.
x = {}
for i in range(num_workers):
    for j in range(num_tasks):
        x[i, j] = solver.IntVar(0, 1, "")
        
# Each worker is assigned to at most 1 task.
for i in range(num_workers):
    solver.Add(solver.Sum([x[i, j] for j in range(num_tasks)]) <= 1)

# Each task is assigned to exactly one worker.
for j in range(num_tasks):
    solver.Add(solver.Sum([x[i, j] for i in range(num_workers)]) == 1)
    
objective_terms = []
for i in tqdm(range(num_workers)):
    for j in range(num_tasks):
        objective_terms.append(costs[i][j] * x[i, j])
solver.Minimize(solver.Sum(objective_terms))

status = solver.Solve()

sol_indexes = []
if status == pywraplp.Solver.OPTIMAL or status == pywraplp.Solver.FEASIBLE:
    print(f"Total cost = {solver.Objective().Value()}\n")
    for i in range(num_workers):
        for j in range(num_tasks):
            # Test if x[i,j] is 1 (with tolerance for floating point arithmetic).
            if x[i, j].solution_value() > 0.1:
                print(f"Cluster {j} assigned to Class {i}." + f" Cost: {costs[i][j]}")
                sol_indexes.append(i)
else:
    print("No solution found.")
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1000/1000 [00
# Cluster 272 assigned to Class 879. Cost: 103.99783944624184
# Cluster 249 assigned to Class 882. Cost: 117.9553800559704
# Cluster 327 assigned to Class 887. Cost: 95.43591029796983
# Cluster 215 assigned to Class 889. Cost: 81.67257901596157
# Cluster 232 assigned to Class 891. Cost: 85.9920825609386
# Cluster 102 assigned to Class 892. Cost: 136.21551240602474
# Cluster 17 assigned to Class 893. Cost: 108.96223874306706
# Cluster 79 assigned to Class 897. Cost: 91.1050229789644
# Cluster 167 assigned to Class 902. Cost: 92.7786133521097
# Cluster 177 assigned to Class 903. Cost: 89.0673900607572
# Cluster 227 assigned to Class 906. Cost: 63.051315108052776
# Cluster 246 assigned to Class 907. Cost: 73.48516976399549
# Cluster 326 assigned to Class 909. Cost: 88.28153324042613
# Cluster 58 assigned to Class 910. Cost: 149.010406673067
# Cluster 16 assigned to Class 920. Cost: 129.89209667849528
# Cluster 65 assigned to Class 923. Cost: 65.65613561292352
# Cluster 313 assigned to Class 924. Cost: 90.54270676591572
# Cluster 271 assigned to Class 925. Cost: 81.76840270254463
# Cluster 306 assigned to Class 926. Cost: 114.77628768871601
# Cluster 146 assigned to Class 928. Cost: 76.53497552518606
# Cluster 267 assigned to Class 929. Cost: 107.11802067439848
# Cluster 21 assigned to Class 932. Cost: 106.82067269851578
# Cluster 334 assigned to Class 933. Cost: 122.75738792659511
# Cluster 23 assigned to Class 934. Cost: 81.62401527810518
# Cluster 194 assigned to Class 935. Cost: 85.46505942164043
# Cluster 143 assigned to Class 938. Cost: 115.51832788028754
# Cluster 398 assigned to Class 939. Cost: 124.3239826036485
# Cluster 261 assigned to Class 941. Cost: 97.57669222561128
# Cluster 229 assigned to Class 943. Cost: 128.60951653922282
# Cluster 88 assigned to Class 947. Cost: 124.48171991026277
# Cluster 25 assigned to Class 949. Cost: 117.40551875861593
# Cluster 242 assigned to Class 952. Cost: 90.62393549357218
# Cluster 350 assigned to Class 956. Cost: 114.30061083989851
# Cluster 363 assigned to Class 957. Cost: 94.97057874532128
# Cluster 374 assigned to Class 960. Cost: 58.5769087367756
# Cluster 39 assigned to Class 962. Cost: 97.31043146819077
# Cluster 346 assigned to Class 965. Cost: 85.12006619125889
# Cluster 24 assigned to Class 966. Cost: 85.72077124728187
# Cluster 325 assigned to Class 967. Cost: 61.11327795282814
# Cluster 142 assigned to Class 968. Cost: 89.92639577805237
# Cluster 27 assigned to Class 969. Cost: 100.34817132944895
# Cluster 202 assigned to Class 982. Cost: 69.68629276047355
# Cluster 247 assigned to Class 985. Cost: 71.792196198749
# Cluster 216 assigned to Class 990. Cost: 86.4609088844194
# Cluster 195 assigned to Class 994. Cost: 108.98457368095931
# Cluster 155 assigned to Class 995. Cost: 99.3256443712472
# Cluster 367 assigned to Class 999. Cost: 114.1171584326634

# %%
import pickle

# Saving the list to a file in the D: drive
file_path = r"D:\index_list.pickle"  # r prefix is used for raw string to avoid escape characters

with open(file_path, 'wb') as file:
    pickle.dump(sol_indexes, file)

print("Combo list saved successfully.")
# Out:
# Combo list saved successfully.
